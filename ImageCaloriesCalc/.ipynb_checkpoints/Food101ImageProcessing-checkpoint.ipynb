# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers

# Define data directories
train_dir = 'train'
val_dir = 'validation'

# Define image size and batch size
img_size = (224, 224)
batch_size = 32

# Load pre-trained MobileNetV2 model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained weights
for layer in base_model.layers:
    layer.trainable = False

# Build new fully connected neural network
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = layers.Dense(11, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=predictions)

# Compile model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define data generators
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=img_size,
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow_from_directory(val_dir,
                                                target_size=img_size,
                                                batch_size=batch_size,
                                                class_mode='categorical')

# Train model
model.fit(train_generator,
          steps_per_epoch=train_generator.samples // batch_size,
          epochs=10,
          validation_data=val_generator,
          validation_steps=val_generator.samples // batch_size)

# Save trained model
model.save('myfood11_mobilenetv2.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Found 1591 images belonging to 11 classes.
# Found 1591 images belonging to 11 classes.
# Epoch 1/10
# 49/49 [==============================] - 80s 2s/step - loss: 1.0625 - accuracy: 0.6735 - val_loss: 0.3181 - val_accuracy: 0.9101
# Epoch 2/10
# 49/49 [==============================] - 61s 1s/step - loss: 0.4195 - accuracy: 0.8679 - val_loss: 0.2033 - val_accuracy: 0.9349
# Epoch 3/10
# 49/49 [==============================] - 80s 2s/step - loss: 0.3255 - accuracy: 0.8987 - val_loss: 0.1538 - val_accuracy: 0.9477
# Epoch 4/10
# 49/49 [==============================] - 62s 1s/step - loss: 0.2865 - accuracy: 0.9057 - val_loss: 0.1436 - val_accuracy: 0.9534
# Epoch 5/10
# 49/49 [==============================] - 59s 1s/step - loss: 0.2371 - accuracy: 0.9224 - val_loss: 0.1325 - val_accuracy: 0.9592
# Epoch 6/10
# 49/49 [==============================] - 60s 1s/step - loss: 0.2066 - accuracy: 0.9333 - val_loss: 0.1173 - val_accuracy: 0.9579
# Epoch 7/10
# 49/49 [==============================] - 60s 1s/step - loss: 0.1763 - accuracy: 0.9397 - val_loss: 0.1057 - val_accuracy: 0.9688
# Epoch 8/10
# 49/49 [==============================] - 60s 1s/step - loss: 0.1641 - accuracy: 0.9442 - val_loss: 0.0662 - val_accuracy: 0.9790
# Epoch 9/10
# 49/49 [==============================] - 59s 1s/step - loss: 0.1359 - accuracy: 0.9532 - val_loss: 0.0821 - val_accuracy: 0.9739
# Epoch 10/10
# 49/49 [==============================] - 60s 1s/step - loss: 0.1657 - accuracy: 0.9397 - val_loss: 0.0644 - val_accuracy: 0.9796
